# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('dataset/ITC.csv')

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close      Volume
# 0  1996-01-01  5.55000  5.60000  5.53333  5.58333   0.000079    985500.0
# 1  1996-01-02  5.46667  5.56667  5.28889  5.37222   0.000076   7470000.0
# 2  1996-01-03  5.13333  5.25444  5.10111  5.20000   0.000074  15160500.0
# 3  1996-01-04  5.20000  5.33222  5.14444  5.29778   0.000075  12397500.0
# 4  1996-01-05  5.29778  5.27778  5.18889  5.20222   0.000074   5008500.0

# %%
df.isnull().sum()
# Out:
# Date           0
# Open         125
# High         125
# Low          125
# Close        125
# Adj Close    125
# Volume       125
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
pd.to_datetime(df['Date'],format='%Y-%m-%d').dt.year.head()
# Out:
# 0    1996
# 1    1996
# 2    1996
# 3    1996
# 4    1996
# Name: Date, dtype: int64

# %%
df['Year'] = pd.to_datetime(df['Date'],format='%Y-%m-%d').dt.year
df['Month'] = pd.to_datetime(df['Date'],format='%Y-%m-%d').dt.month
df['Day'] = pd.to_datetime(df['Date'],format='%Y-%m-%d').dt.day

# %%
df[['Year','Month','Day']].head()
# Out:
#    Year  Month  Day
# 0  1996      1    1
# 1  1996      1    2
# 2  1996      1    3
# 3  1996      1    4
# 4  1996      1    5

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#       Open     High      Low    Close  Adj Close      Volume  Year  Month  Day
# 0  5.55000  5.60000  5.53333  5.58333   0.000079    985500.0  1996      1    1
# 1  5.46667  5.56667  5.28889  5.37222   0.000076   7470000.0  1996      1    2
# 2  5.13333  5.25444  5.10111  5.20000   0.000074  15160500.0  1996      1    3
# 3  5.20000  5.33222  5.14444  5.29778   0.000075  12397500.0  1996      1    4
# 4  5.29778  5.27778  5.18889  5.20222   0.000074   5008500.0  1996      1    5

# %%
df.shape
# Out:
# (6078, 9)

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999885  0.999856  0.999769   0.997216 -0.319967
# High       0.999885  1.000000  0.999824  0.999896   0.997278 -0.319874
# Low        0.999856  0.999824  1.000000  0.999887   0.997312 -0.319853
# Close      0.999769  0.999896  0.999887  1.000000   0.997326 -0.319873
# Adj Close  0.997216  0.997278  0.997312  0.997326   1.000000 -0.300887
# Volume    -0.319967 -0.319874 -0.319853 -0.319873  -0.300887  1.000000
# Year       0.927172  0.927739  0.926437  0.927087   0.922885 -0.469727
# Month      0.010335  0.009691  0.010358  0.009860   0.012421  0.028526
# Day        0.002473  0.002952  0.002508  0.003052   0.003224 -0.001563
#
#                Year     Month       Day
# Open       0.927172  0.010335  0.002473
# High       0.927739  0.009691  0.002952
# Low        0.926437  0.010358  0.002508
# Close      0.927087  0.009860  0.003052
# Adj Close  0.922885  0.012421  0.003224
# Volume    -0.469727  0.028526 -0.001563
# Year       1.000000 -0.030510  0.000874
# Month     -0.030510  1.000000  0.008572
# Day        0.000874  0.008572  1.000000

# %%
df.corr()>0.90
# Out:
#             Open   High    Low  Close  Adj Close  Volume   Year  Month    Day
# Open        True   True   True   True       True   False   True  False  False
# High        True   True   True   True       True   False   True  False  False
# Low         True   True   True   True       True   False   True  False  False
# Close       True   True   True   True       True   False   True  False  False
# Adj Close   True   True   True   True       True   False   True  False  False
# Volume     False  False  False  False      False    True  False  False  False
# Year        True   True   True   True       True   False   True  False  False
# Month      False  False  False  False      False   False  False   True  False
# Day        False  False  False  False      False   False  False  False   True

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)

# %%
X = df.drop('Adj Close',axis=1)
y = df['Adj Close']

# %%
X.head(2)
# Out:
#       Open     High      Low    Close     Volume  Year  Month  Day
# 0  5.55000  5.60000  5.53333  5.58333   985500.0  1996      1    1
# 1  5.46667  5.56667  5.28889  5.37222  7470000.0  1996      1    2

# %%
y.head(2)
# Out:
# 0    0.000079
# 1    0.000076
# Name: Adj Close, dtype: float64

# %%
max(y)
# Out:
# 313.638275

# %%
min(y)
# Out:
# 5.9e-05

# %%
from sklearn.ensemble import ExtraTreesRegressor,RandomForestRegressor

# %%
etr = ExtraTreesRegressor()

# %%
etr.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
etr.feature_importances_
# Out:
# array([2.07011913e-01, 2.57503137e-01, 2.11074099e-01, 1.94469323e-01,
#        1.28658388e-05, 1.29654802e-01, 2.44444827e-04, 2.94164507e-05])

# %%
imp_features = pd.Series(data=etr.feature_importances_,index=X.columns)

# %%
imp_features
# Out:
# Open      0.207012
# High      0.257503
# Low       0.211074
# Close     0.194469
# Volume    0.000013
# Year      0.129655
# Month     0.000244
# Day       0.000029
# dtype: float64

# %%
sns.barplot(y=etr.feature_importances_,x=X.columns)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
np.linspace(100,1000,10)
# Out:
# array([ 100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,  900.,
#        1000.])

# %%
n_estimator = [i for i in np.linspace(100,1000,10)]

# %%
param = {'n_estimators':n_estimator}

# %%
rfr = RandomForestRegressor(n_estimators=200)

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
pred = rfr.predict(X_test)

# %%
plt.hist((y_test-pred),bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 3.000e+00, 0.000e+00, 1.000e+00, 3.000e+00,
#         1.000e+00, 0.000e+00, 3.000e+00, 2.000e+00, 3.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 5.000e+00, 4.000e+00, 4.000e+00, 1.100e+01,
#         6.000e+00, 6.000e+00, 7.000e+00, 1.100e+01, 6.000e+00, 1.100e+01,
#         1.600e+01, 1.800e+01, 2.600e+01, 2.700e+01, 4.900e+01, 7.500e+01,
#         1.500e+02, 1.065e+03, 1.190e+02, 7.400e+01, 5.200e+01, 3.500e+01,
#         2.800e+01, 3.100e+01, 2.600e+01, 2.200e+01, 1.600e+01, 1.100e+01,
#         9.000e+00, 3.000e+00, 5.000e+00, 6.000e+00, 7.000e+00, 2.000e+00,
#         4.000e+00, 6.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 5.000e+00,
#         2.000e+00, 1.000e+00, 3.000e+00, 4.000e+00, 1.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-7.95615764, -7.7946184 , -7.63307915, -7.4715399 , -7.31000065,
#         -7.1484614 , -6.98692215, -6.8253829 , -6.66384365, -6.5023044 ,
#         -6.34076515, -6.1792259 , -6.01768666, -5.85614741, -5.69460816,
#         -5.53306891, -5.37152966, -5.20999041, -5.04845116, -4.88691191,
#         -4.72537266, -4.56383341, -4.40229416, -4.24075491, -4.07921567,
#         -3.91767642, -3.75613717, -3.59459792, -3.43305867, -3.27151942,
#         -3.10998017, -2.94844092, -2.78690167, -2.62536242, -2.46382317,
#         -2.30228392, -2.14074468, -1.97920543, -1.81766618, -1.65612693,
#         -1.49458768, -1.33304843, -1.17150918, -1.00996993, -0.84843068,
#         -0.68689143, -0.52535218, -0.36381293, -0.20227369, -0.04073444,
#          0.12080481,  0.28234406,  0.44388331,  0.60542256,  0.76696181,
#          0.92850106,  1.09004031,  1.25157956,  1.41311881,  1.57465805,
#          1.7361973 ,  1.89773655,  2.0592758 ,  2.22081505,  2.3823543 ,
#          2.54389355,  2.7054328 ,  2.86697205,  3.0285113 ,  3.19005055,
#          3.3515898 ,  3.51312904,  3.67466829,  3.83620754,  3.99774679,
#          4.15928604,  4.32082529,  4.48236454,  4.64390379,  4.80544304,
#          4.96698229,  5.12852154,  5.29006079,  5.45160003,  5.61313928,
#          5.77467853,  5.93621778,  6.09775703,  6.25929628,  6.42083553,
#          6.58237478,  6.74391403,  6.90545328,  7.06699253,  7.22853178,
#          7.39007102,  7.55161027,  7.71314952,  7.87468877,  8.03622802,
#          8.19776727]),
#  <a list of 100 Patch objects>)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,pred)
# Out:
# 0.428995881456584

# %%
mean_squared_error(y_test,pred)
# Out:
# 0.9398792956291593

# %%
import math
math.sqrt(mean_squared_error(y_test,pred))
# Out:
# 0.9694737209585205

# %%
plt.scatter(y_test,pred)

# %%
import pickle

# %%
file_out = open('ITC_Stock_Price.pkl','wb')
pickle.dump(rfr,file_out)
file_out.close()
